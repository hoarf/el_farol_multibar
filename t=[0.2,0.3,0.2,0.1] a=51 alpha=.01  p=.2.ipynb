# %%
cd /vagrant_data/src/reinforcement-learning-practice/
# Out:
# /vagrant_data/src/reinforcement-learning-practice

# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# Asserting the code version this was run
# !git log -n 1 --format=oneline -- wlu.py 
# !git status -s wlu.py
# Out:
# e2b57a056361d60e07dc26be695a4f3acd0dea24 Add decay message and set default p to 1.0

# %%
from wlu import Experiment

# %% [markdown]
# # Experiment WITH WLU:

# %% [markdown]
# ## #1) thresholds=[0.2,0.3,0.2,0.1], nr_agents=51, use_wlu=True, alpha=.01, p=.2

# %%
na = 51

experiment = Experiment(thresholds=[0.2,0.3,0.2,0.1], nr_agents=na, debug=True, use_wlu=True, alpha=.01, p=.2)

weekly_attendance_data, world_utilities, agent_q_values = experiment.run()
# Out:
#  --- Running experiment ---
# DEBUG MODE: True
#  Parameters:
# LEARNING RATE: 0.01
# THRESHOLDS: [0.2, 0.3, 0.2, 0.1]
# NUMBER OF AGENTS: 51
# NUMBER OF BARS: 4
# NUMBER OF WEEKS: 5000
# INITIAL_EXPLORATION_CHANCE: 0.2
# DECAY: No
# REWARD TYPE: WLU
# -----------------
# Week 0
# Agent N q-values before receiving reward [ 0.  0.  0.  0.  0.]
# Agent N action 0
# Bar attendances [  8.   5.  10.  11.  17.]
# Bar results [ 1.  1.  0.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-2.037  0.     0.     0.     0.   ]
# World utility: 0.0
# World utility w/o Agent N: -203.7
# -----------------
# Week 500
# Agent N q-values before receiving reward [-14.33576574 -13.14499255 -11.12899475 -14.77747874 -15.91639246]
# Agent N action 2
# Bar attendances [ 14.   2.   4.  15.  16.]
# Bar results [ 1.  1.  0.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-14.33576574 -13.14499255 -11.0177048  -14.77747874 -15.91639246]
# World utility: 0.0
# World utility w/o Agent N: 0.0
# -----------------
# Week 1000
# Agent N q-values before receiving reward [-19.44405548 -25.29334536 -25.16797316 -25.25290897 -26.14897267]
# Agent N action 0
# Bar attendances [ 15.  17.   5.   4.  10.]
# Bar results [ 0.  1.  1.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-19.24961492 -25.29334536 -25.16797316 -25.25290897 -26.14897267]
# World utility: 0.0
# World utility w/o Agent N: 0.0
# -----------------
# Week 1500
# Agent N q-values before receiving reward [-11.29472192 -21.16092793 -21.76727276 -21.06667366 -22.42628934]
# Agent N action 0
# Bar attendances [ 18.  17.   4.   1.  11.]
# Bar results [ 0.  1.  1.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-11.18177471 -21.16092793 -21.76727276 -21.06667366 -22.42628934]
# World utility: 0.0
# World utility w/o Agent N: 0.0
# -----------------
# Week 2000
# Agent N q-values before receiving reward [ -5.74957851 -16.80806349 -19.12975032 -17.61709016 -20.87673745]
# Agent N action 0
# Bar attendances [ 13.  14.   6.   2.  16.]
# Bar results [ 0.  1.  1.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [ -5.69208272 -16.80806349 -19.12975032 -17.61709016 -20.87673745]
# World utility: 0.0
# World utility w/o Agent N: 0.0
# -----------------
# Week 2500
# Agent N q-values before receiving reward [-23.22169563 -22.28566863 -12.80999837 -23.57290949 -21.80603792]
# Agent N action 2
# Bar attendances [  6.  23.   3.  16.   3.]
# Bar results [ 0.  1.  0.  1.]
# List of rewards [   0.    0.    0.    0.  679.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-23.22169563 -22.28566863 -12.68988662 -23.57290949 -21.80603792]
# World utility: 39.9411764706
# World utility w/o Agent N: -0.798823529412
# -----------------
# Week 3000
# Agent N q-values before receiving reward [-18.6873632  -18.26283027  -2.31595042 -19.17936854 -18.84585135]
# Agent N action 2
# Bar attendances [  9.  19.   6.  15.   2.]
# Bar results [ 0.  1.  0.  1.]
# List of rewards [   0.    0.    0.    0.  679.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-18.6873632  -18.26283027  -2.2981164  -19.17936854 -18.84585135]
# World utility: 26.6274509804
# World utility w/o Agent N: -0.532549019608
# -----------------
# Week 3500
# Agent N q-values before receiving reward [-15.67438748 -14.71829094  -2.03428708 -15.04381407 -14.48336594]
# Agent N action 2
# Bar attendances [  8.  24.   4.  14.   1.]
# Bar results [ 0.  1.  0.  1.]
# List of rewards [   0.    0.    0.    0.  679.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-15.67438748 -14.71829094  -2.01660696 -15.04381407 -14.48336594]
# World utility: 13.3137254902
# World utility w/o Agent N: -0.266274509804
# -----------------
# Week 4000
# Agent N q-values before receiving reward [-16.7996359  -20.30240482 -19.976169   -19.30795707 -20.95472328]
# Agent N action 0
# Bar attendances [ 14.   3.   6.  14.  14.]
# Bar results [ 1.  1.  0.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-16.63163954 -20.30240482 -19.976169   -19.30795707 -20.95472328]
# World utility: 0.0
# World utility w/o Agent N: 0.0
# -----------------
# Week 4500
# Agent N q-values before receiving reward [-20.71843669  -9.75873922 -19.06279333 -19.58262048 -19.01233775]
# Agent N action 1
# Bar attendances [ 10.  21.   3.   5.  12.]
# Bar results [ 0.  1.  1.  0.]
# List of rewards [ 0.  0.  0.  0.  0.]
# Exploration probability 0.2
# Agent N q-values after receiving reward [-20.71843669 -10.34015183 -19.06279333 -19.58262048 -19.01233775]
# World utility: 0.0
# World utility w/o Agent N: -67.9

# %% [markdown]
# ### Experiment #1 Results:
#
# #### Agent Q-Values
#
# ##### Q-Values for 3 random agents

# %%
chosen_agents_ix = np.random.choice(na, 6)
print "Chosen agents: %s" % chosen_agents_ix[0:3]
experiment.plot_q_values(agent_q_values[chosen_agents_ix[0:3]])
# Out:
# Chosen agents: [22 16 15]

# %% [markdown]
# ##### Q-Values for the first 3 agents

# %%
experiment.plot_q_values(agent_q_values[:3])

# %% [markdown]
# # Experiment WITHOUT WLU

# %% [markdown]
# ## #2) thresholds=[0.2,0.3,0.2,0.1], nr_agents=51, use_wlu=False, alpha=.01, p=.2

# %%
na = 51

experiment = Experiment(thresholds=[0.2,0.3,0.2,0.1], nr_agents=na, debug=False, use_wlu=False, alpha=.01, p=.2)

weekly_attendance_data, world_utilities, agent_q_values = experiment.run()
# Out:
#  --- Running experiment ---
# DEBUG MODE: False
#  Parameters:
# LEARNING RATE: 0.01
# THRESHOLDS: [0.2, 0.3, 0.2, 0.1]
# NUMBER OF AGENTS: 51
# NUMBER OF BARS: 4
# NUMBER OF WEEKS: 5000
# INITIAL_EXPLORATION_CHANCE: 0.2
# DECAY: No
# REWARD TYPE: REGULAR

# %% [markdown]
# ### Experiment #2 Results:
#
# #### Agent Q-Values
#
# ##### Q-Values for 3 random agents

# %%
chosen_agents_ix = np.random.choice(na, 6)
print "Chosen agents: %s" % chosen_agents_ix[0:3]
experiment.plot_q_values(agent_q_values[chosen_agents_ix[0:3]])
# Out:
# Chosen agents: [26 24  0]

# %% [markdown]
# ##### Q-Values for the first 3 agents

# %%
experiment.plot_q_values(agent_q_values[:3])
