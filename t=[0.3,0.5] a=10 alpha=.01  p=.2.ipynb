# %%
cd /vagrant_data/src/rl
# Out:
# /vagrant_data/src/rl

# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Asserting the code version this was run
# !git log -n 1 --format=oneline -- wlu.py 
# !git status -s wlu.py
from wlu import Experiment
# Out:
# 9d958d3cdcc67e995b118e7cdddc9d2bebd32839 Fixed Y label for reward plot
#  M wlu.py

# %% [markdown]
# # Experiment WITH WLU:

# %% [markdown]
# ## #1) thresholds=[0.3,0.5], nr_agents=10, use_wlu=True, alpha=.01, p=.2

# %%
experiment = Experiment(thresholds=[0.3,0.5], nr_agents=10, debug=False, use_wlu=True, alpha=.01, p=.2)

weekly_attendance_data, world_utilities, agent_q_values, rewards, actions = experiment.run()
# Out:
#  --- Running experiment ---
# DEBUG MODE: False
#  Parameters:
# LEARNING RATE: 0.01
# THRESHOLDS: [0.3, 0.5]
# NUMBER OF AGENTS: 10
# NUMBER OF BARS: 2
# NUMBER OF WEEKS: 5000
# INITIAL EXPLORATION CHANCE 0.2
# DECAY: No
# REWARD TYPE: WLU

# %% [markdown]
# ### Experiment #1 Results:
#
# #### Agent Q-Values for each of the 10 agents
#
# ##### Agents 0-4

# %%
experiment.plot_q_values(agent_q_values[0:4])

# %% [markdown]
# ##### Agents 4-8

# %%
experiment.plot_q_values(agent_q_values[4:8])

# %% [markdown]
# #### Agents 8-10

# %%
experiment.plot_q_values(agent_q_values[8:10])

# %%
experiment.plot_rewards(rewards[0:2])

# %%
experiment.plot_world_utilities(world_utilities)

# %% [markdown]
# # Experiment WITHOUT WLU

# %% [markdown]
# ## #2) thresholds=[0.3,0.5], nr_agents=10, use_wlu=False, alpha=.01, p=.2

# %%
experiment = Experiment(thresholds=[0.3,0.5], nr_agents=10, debug=False, use_wlu=False, alpha=.01, p=.2)

weekly_attendance_data, world_utilities, agent_q_values, rewards, actions = experiment.run()
# Out:
#  --- Running experiment ---
# DEBUG MODE: False
#  Parameters:
# LEARNING RATE: 0.01
# THRESHOLDS: [0.3, 0.5]
# NUMBER OF AGENTS: 10
# NUMBER OF BARS: 2
# NUMBER OF WEEKS: 5000
# INITIAL EXPLORATION CHANCE 0.2
# DECAY: No
# REWARD TYPE: REGULAR

# %% [markdown]
# ### Experiment #2 Results:
#
# #### Agent Q-Values for each of the 10 agents
#
# ##### Agents 1-4

# %%
experiment.plot_q_values(agent_q_values[0:4])

# %% [markdown]
# ##### Agents 4-8

# %%
experiment.plot_q_values(agent_q_values[4:8])

# %% [markdown]
# ##### Agents 8-10

# %%
experiment.plot_q_values(agent_q_values[8:10])
